# %% [markdown]
# # **UNET MODEL**

# %%
import numpy as np

from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose, multiply, Lambda, add, Activation
from keras.layers import concatenate
from keras.optimizers import *
import keras.backend as K
from keras.callbacks import EarlyStopping
from keras.preprocessing import image

import tensorflow as tf

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix
from sklearn.model_selection import KFold

import os
from os import listdir

import natsort # it may need to be installed by 'pip install natsort'

import datetime
now = datetime.datetime.now

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        pass
       # print(os.path.join(dirname, filename))

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
from PIL import Image
import tensorflow as ft
import glob

# %%
benign ='/content/drive/MyDrive/Dataset_BUSI_with_GT/benign'
malignant='/content/drive/MyDrive/Dataset_BUSI_with_GT/malignant'
normal='/content/drive/MyDrive/Dataset_BUSI_with_GT/normal'

# %%
count_benign=len(os.listdir(benign))
count_malignant=len(os.listdir(malignant))
count_normal=len(os.listdir(normal))

# %%
# Get the list of all the images
bening_cases = glob.glob(benign+ '/*')
malignant_cases =glob.glob(malignant+ '/*')
normal_cases = glob.glob(normal+ '/*')

# An empty list. We will insert the data into this list in (img_path, label) format
exclude=[]
train_data_mask = []
train_data_img=[]
# Go through all the normal cases. The label for these cases will be 0
for img in normal_cases:
    if img.endswith('_mask.png'):
        train_data_mask.append(img)
    elif img.endswith('_mask_1.png') or img.endswith('_mask_2.png'):
        exclude.append(img)
    else :
        train_data_img.append(img)

# Go through all the bening cases. The label for these cases will be 1
for img in bening_cases:
    if img.endswith('_mask.png'):
        train_data_mask.append(img)
    elif img.endswith('_mask_1.png') or img.endswith('_mask_2.png'):
        exclude.append(img)
    else:
        train_data_img.append(img)

# Go through all the malignant cases. The label for these cases will be 1
for img in malignant_cases:

    if img.endswith('_mask.png'):
        train_data_mask.append(img)
    elif img.endswith('_mask_1.png') or img.endswith('_mask_2.png'):
        exclude.append(img)
    else:
        train_data_img.append(img)

# %%
train_data_img = sorted(train_data_img)
train_data_mask = sorted(train_data_mask)

# %%
len(train_data_img), len(train_data_mask), len(exclude)
# Out:
# (780, 780, 18)

# %%
train_data_img[100]
# Out:
# '/content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (19).png'

# %%
train_data_mask[100]
# Out:
# '/content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (19)_mask.png'

# %%
images=[]
masks=[]
size_x=128
size_y=128

for every_img_path in train_data_img:
    img=cv2.imread(every_img_path,cv2.IMREAD_COLOR)
    img=cv2.resize(img,(size_y, size_x))
    images.append(img)

for every_mask_path in train_data_mask:
    mask=cv2.imread(every_mask_path,0)
    mask=cv2.resize(mask,(size_y,size_x))
    masks.append(mask)

images = np.array(images)
masks = np.array(masks)

# %%
x=images/255
y=masks/255

# %%
import random
from skimage.io import imshow

########## Displaying random image from X_train and Y_train #########
random_num = random.randint(0,516)
imshow(x[random_num])
plt.show()
imshow(y[random_num])
plt.show()

test_img = x[random_num]
test_img2 = y[random_num]
print(test_img.min(), test_img.max())
print(test_img.shape)

print(test_img2.min(), test_img2.max())
print(test_img2.shape)
# Out:
# 0.0 0.9254901960784314
# (128, 128, 3)
# 0.0 1.0
# (128, 128)

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras.models import Model

IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3

def simple_unet_model(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS):
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    #s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    s = inputs

    #Contraction path
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
    c1 = Dropout(0.1)(c1)
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.1)(c2)
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)

    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

    #Expansive path
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.1)(c8)
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.1)(c9)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)

    model = Model(inputs=[inputs], outputs=[outputs])
    # model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    # model.summary()

    return model

# %%
def get_model():
    return simple_unet_model(IMG_HEIGHT,IMG_WIDTH,IMG_CHANNELS)

# %%
model = get_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 128, 128, 16)         448       ['input_1[0][0]']
#
#  dropout (Dropout)           (None, 128, 128, 16)         0         ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 16)         2320      ['dropout[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 16)           0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 32)           4640      ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)         (None, 64, 64, 32)           0         ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 32)           9248      ['dropout_1[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 32)           0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 64)           18496     ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 32, 32, 64)           0         ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 64)           36928     ['dropout_2[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 64)           0         ['conv2d_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 128)          73856     ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 16, 16, 128)          0         ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 128)          147584    ['dropout_3[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 8, 8, 128)            0         ['conv2d_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 256)            295168    ['max_pooling2d_3[0][0]']
#
#  dropout_4 (Dropout)         (None, 8, 8, 256)            0         ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 256)            590080    ['dropout_4[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 16, 16, 128)          131200    ['conv2d_9[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 16, 16, 256)          0         ['conv2d_transpose[0][0]',
#                                                                      'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 128)          295040    ['concatenate[0][0]']
#
#  dropout_5 (Dropout)         (None, 16, 16, 128)          0         ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 128)          147584    ['dropout_5[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 32, 32, 64)           32832     ['conv2d_11[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 32, 32, 128)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 32, 32, 64)           73792     ['concatenate_1[0][0]']
#
#  dropout_6 (Dropout)         (None, 32, 32, 64)           0         ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 64)           36928     ['dropout_6[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 64, 64, 32)           8224      ['conv2d_13[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 64, 64, 64)           0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 64, 64, 32)           18464     ['concatenate_2[0][0]']
#
#  dropout_7 (Dropout)         (None, 64, 64, 32)           0         ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 64, 64, 32)           9248      ['dropout_7[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 128, 128, 16)         2064      ['conv2d_15[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 128, 128, 32)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 128, 128, 16)         4624      ['concatenate_3[0][0]']
#
#  dropout_8 (Dropout)         (None, 128, 128, 16)         0         ['conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 128, 128, 16)         2320      ['dropout_8[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 128, 128, 1)          17        ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 1941105 (7.40 MB)
# Trainable params: 1941105 (7.40 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['mse'])

# %%
history=model.fit(x_train,
          y_train,
          batch_size=20,
          epochs=50,
          verbose=1,
          validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 32/32 [==============================] - 126s 4s/step - loss: 0.3555 - mse: 0.0906 - val_loss: 0.2897 - val_mse: 0.0767
# Epoch 2/50
# 32/32 [==============================] - 120s 4s/step - loss: 0.2498 - mse: 0.0673 - val_loss: 0.2379 - val_mse: 0.0650
# Epoch 3/50
# 32/32 [==============================] - 122s 4s/step - loss: 0.2056 - mse: 0.0576 - val_loss: 0.2137 - val_mse: 0.0596
# Epoch 4/50
# 32/32 [==============================] - 121s 4s/step - loss: 0.1922 - mse: 0.0542 - val_loss: 0.1854 - val_mse: 0.0525
# Epoch 5/50
# 32/32 [==============================] - 120s 4s/step - loss: 0.1797 - mse: 0.0500 - val_loss: 0.1933 - val_mse: 0.0542
# Epoch 6/50
# 32/32 [==============================] - 120s 4s/step - loss: 0.1727 - mse: 0.0484 - val_loss: 0.1742 - val_mse: 0.0502
# Epoch 7/50
# 32/32 [==============================] - 120s 4s/step - loss: 0.1717 - mse: 0.0481 - val_loss: 0.1995 - val_mse: 0.0556
# Epoch 8/50
# 32/32 [==============================] - 120s 4s/step - loss: 0.1725 - mse: 0.0482 - val_loss: 0.1841 - val_mse: 0.0532
# Epoch 9/50
# 32/32 [==============================] - 121s 4s/step - loss: 0.1664 - mse: 0.0464 - val_loss: 0.1846 - val_mse: 0.0518
# Epoch 10/50
# 32/32 [==============================] - 118s 4s/step - loss: 0.1574 - mse: 0.0430 - val_loss: 0.1749 - val_mse: 0.0490
# Epoch 11/50
# 32/32 [==============================] - 120s 4s/step - loss: 0.1487 - mse: 0.0412 - val_loss: 0.1507 - val_mse: 0.0425
# Epoch 12/50
# 32/32 [==============================] - 117s 4s/step - loss: 0.1406 - mse: 0.0390 - val_loss: 0.1439 - val_mse: 0.0406
# Epoch 13/50
# 32/32 [==============================] - 121s 4s/step - loss: 0.1444 - mse: 0.0392 - val_loss: 0.1536 - val_mse: 0.0424
# Epoch 14/50
# 32/32 [==============================] - 121s 4s/step - loss: 0.1392 - mse: 0.0383 - val_loss: 0.1469 - val_mse: 0.0414
# Epoch 15/50
# 32/32 [==============================] - 121s 4s/step - loss: 0.1341 - mse: 0.0369 - val_loss: 0.1560 - val_mse: 0.0442
# Epoch 16/50
# 32/32 [==============================] - 121s 4s/step - loss: 0.1289 - mse: 0.0357 - val_loss: 0.1503 - val_mse: 0.0418
# Epoch 17/50
# 32/32 [==============================] - 122s 4s/step - loss: 0.1278 - mse: 0.0354 - val_loss: 0.1309 - val_mse: 0.0368
# Epoch 18/50
# 32/32 [==============================] - 119s 4s/step - loss: 0.1178 - mse: 0.0328 - val_loss: 0.1336 - val_mse: 0.0376
# Epoch 19/50
# 32/32 [==============================] - 123s 4s/step - loss: 0.1110 - mse: 0.0304 - val_loss: 0.1345 - val_mse: 0.0370
# Epoch 20/50
# 32/32 [==============================] - 118s 4s/step - loss: 0.1117 - mse: 0.0308 - val_loss: 0.1285 - val_mse: 0.0343
# Epoch 21/50
# 32/32 [==============================] - 121s 4s/step - loss: 0.1012 - mse: 0.0275 - val_loss: 0.1235 - val_mse: 0.0340
# Epoch 22/50
# 32/32 [==============================] - 123s 4s/step - loss: 0.0954 - mse: 0.0262 - val_loss: 0.1188 - val_mse: 0.0322
# Epoch 23/50
# 32/32 [==============================] - 123s 4s/step - loss: 0.0890 - mse: 0.0246 - val_loss: 0.1199 - val_mse: 0.0334
# Epoch 24/50
# 32/32 [==============================] - 122s 4s/step - loss: 0.0978 - mse: 0.0273 - val_loss: 0.1263 - val_mse: 0.0360
# Epoch 25/50
# 32/32 [==============================] - 125s 4s/step - loss: 0.1049 - mse: 0.0289 - val_loss: 0.1238 - val_mse: 0.0355
# Epoch 26/50
# 32/32 [==============================] - 125s 4s/step - loss: 0.0833 - mse: 0.0231 - val_loss: 0.1136 - val_mse: 0.0309
# Epoch 27/50
# 32/32 [==============================] - 118s 4s/step - loss: 0.0733 - mse: 0.0205 - val_loss: 0.1174 - val_mse: 0.0327
# Epoch 28/50
# 32/32 [==============================] - 120s 4s/step - loss: 0.0736 - mse: 0.0206 - val_loss: 0.1178 - val_mse: 0.0302
# Epoch 29/50
# 32/32 [==============================] - 122s 4s/step - loss: 0.0741 - mse: 0.0205 - val_loss: 0.1162 - val_mse: 0.0306
# Epoch 30/50
# 32/32 [==============================] - 124s 4s/step - loss: 0.0652 - mse: 0.0184 - val_loss: 0.1189 - val_mse: 0.0305
# Epoch 31/50
# 32/32 [==============================] - 125s 4s/step - loss: 0.0632 - mse: 0.0179 - val_loss: 0.1319 - val_mse: 0.0318
# Epoch 32/50
# 32/32 [==============================] - 122s 4s/step - loss: 0.0619 - mse: 0.0177 - val_loss: 0.1265 - val_mse: 0.0291
# Epoch 33/50
# 32/32 [==============================] - 125s 4s/step - loss: 0.0576 - mse: 0.0162 - val_loss: 0.1118 - val_mse: 0.0292
# Epoch 34/50
# 32/32 [==============================] - 124s 4s/step - loss: 0.0546 - mse: 0.0155 - val_loss: 0.1144 - val_mse: 0.0301
# Epoch 35/50
# 32/32 [==============================] - 121s 4s/step - loss: 0.0521 - mse: 0.0147 - val_loss: 0.1123 - val_mse: 0.0306
# Epoch 36/50
# 32/32 [==============================] - 122s 4s/step - loss: 0.0567 - mse: 0.0159 - val_loss: 0.1088 - val_mse: 0.0283
# Epoch 37/50
# 32/32 [==============================] - 124s 4s/step - loss: 0.0498 - mse: 0.0142 - val_loss: 0.1318 - val_mse: 0.0286
# Epoch 38/50
# 32/32 [==============================] - 120s 4s/step - loss: 0.0450 - mse: 0.0128 - val_loss: 0.1228 - val_mse: 0.0303
# Epoch 39/50
# 32/32 [==============================] - 121s 4s/step - loss: 0.0474 - mse: 0.0134 - val_loss: 0.1107 - val_mse: 0.0278
# Epoch 40/50
# 32/32 [==============================] - 116s 4s/step - loss: 0.0462 - mse: 0.0130 - val_loss: 0.1514 - val_mse: 0.0322
# Epoch 41/50
# 32/32 [==============================] - 119s 4s/step - loss: 0.0501 - mse: 0.0144 - val_loss: 0.1114 - val_mse: 0.0274
# Epoch 42/50
# 32/32 [==============================] - 120s 4s/step - loss: 0.0433 - mse: 0.0125 - val_loss: 0.1300 - val_mse: 0.0290
# Epoch 43/50
# 32/32 [==============================] - 115s 4s/step - loss: 0.0410 - mse: 0.0118 - val_loss: 0.1907 - val_mse: 0.0315
# Epoch 44/50
# 32/32 [==============================] - 120s 4s/step - loss: 0.0429 - mse: 0.0123 - val_loss: 0.1238 - val_mse: 0.0272
# Epoch 45/50
# 32/32 [==============================] - 121s 4s/step - loss: 0.0400 - mse: 0.0115 - val_loss: 0.1313 - val_mse: 0.0278
# Epoch 46/50
# 32/32 [==============================] - 116s 4s/step - loss: 0.0385 - mse: 0.0109 - val_loss: 0.1297 - val_mse: 0.0294
# Epoch 47/50
# 32/32 [==============================] - 119s 4s/step - loss: 0.0389 - mse: 0.0111 - val_loss: 0.1192 - val_mse: 0.0277
# Epoch 48/50
# 32/32 [==============================] - 120s 4s/step - loss: 0.0361 - mse: 0.0104 - val_loss: 0.1342 - val_mse: 0.0288
# Epoch 49/50
# 32/32 [==============================] - 119s 4s/step - loss: 0.0340 - mse: 0.0099 - val_loss: 0.1372 - val_mse: 0.0277
# Epoch 50/50
# 32/32 [==============================] - 118s 4s/step - loss: 0.0332 - mse: 0.0096 - val_loss: 0.1398 - val_mse: 0.0298

# %%
import numpy as np

def dice_coef(y_true, y_pred):

    y_pred = y_pred.reshape(y_true.shape)

    intersection = np.sum(y_true * y_pred)
    union = np.sum(y_true) + np.sum(y_pred)
    return (2.0 * intersection) / (union + 1e-5)

def jaccard_index(y_true, y_pred):

    y_pred = y_pred.reshape(y_true.shape)

    intersection = np.sum(y_true * y_pred)
    union = np.sum(y_true) + np.sum(y_pred) - intersection
    return (intersection) / (union + 1e-5)

def true_positives_ratio(y_true, y_pred):

    y_pred = y_pred.reshape(y_true.shape)

    true_positives = np.sum(y_true * y_pred)
    total_positives = np.sum(y_true)
    return (true_positives) / (total_positives + 1e-5)

def false_positives_ratio(y_true, y_pred):

    y_pred = y_pred.reshape(y_true.shape)

    false_positives = np.sum((1 - y_true) * y_pred)
    total_negatives = np.sum(1 - y_true)
    return (false_positives) / (total_negatives + 1e-5)

def global_accuracy(y_true, y_pred):

    y_pred = y_pred.reshape(y_true.shape)

    correct_predictions = np.sum((y_true == 1) & (y_pred >= 0.5)) + np.sum((y_true == 0) & (y_pred < 0.5))
    total_predictions = y_true.size
    return (correct_predictions) / (total_predictions + 1e-5)


y_pred = model.predict(x_val)
y_pred = (y_pred > 0.5).astype(int)

dsc = dice_coef(y_val, y_pred)
ji = jaccard_index(y_val, y_pred)
tpr = true_positives_ratio(y_val, y_pred)
fpr = false_positives_ratio(y_val, y_pred)
acc = global_accuracy(y_val, y_pred)

print(f"Dice Similarity Coefficient (DSC): {dsc}")
print(f"Jaccard Index (JI): {ji}")
print(f"True Positives Ratio (TPR): {tpr}")
print(f"False Positives Ratio (FPR): {fpr}")
print(f"Global Accuracy (ACC): {acc}")
# Out:
# 5/5 [==============================] - 8s 2s/step
# Dice Similarity Coefficient (DSC): 0.7407927259181741
# Jaccard Index (JI): 0.5883008629046691
# True Positives Ratio (TPR): 0.696090128445522
# False Positives Ratio (FPR): 0.015164145819616393
# Global Accuracy (ACC): 0.9616965269393463

# %% [markdown]
# https://www.kaggle.com/code/owaistahir/unet-for-breast-cancer-tumors-segmentation

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# Load images from the dataset
dataset_path = '/content/drive/MyDrive/Dataset_BUSI_with_GT'  # Update with your dataset path

folders = ['benign', 'malignant', 'normal']
images = []
masks = []

size_x = 128
size_y = 128

for folder in folders:
    folder_path = os.path.join(dataset_path, folder)
    for filename in os.listdir(folder_path):
        if filename.endswith(".png") and not filename.endswith("_mask.png"):
            img_path = os.path.join(folder_path, filename)
            mask_path = os.path.join(folder_path, filename.replace(".png", "_mask.png"))

            img = cv2.imread(img_path, cv2.IMREAD_COLOR)
            mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)  # Read mask as grayscale

            if img is not None and mask is not None:  # Check if both image and mask were read successfully
                img = cv2.resize(img, (size_y, size_x))
                mask = cv2.resize(mask, (size_y, size_x))

                images.append(img)
                masks.append(mask)
            else:
                print(f"Skipped: {img_path} or {mask_path}")

# Convert images and masks to numpy arrays
images = np.array(images)
masks = np.array(masks)

x = images / 255  # Normalize images
y = masks / 255  # Normalize masks

# Make predictions using the trained model
predictions = model.predict(x)

# Threshold the predictions if needed
threshold = 0.5  # Adjust the threshold as needed
binary_predictions = (predictions > threshold).astype(np.uint8)

# Display a few predictions
num_images_to_display = 3  # Change this to set the number of images to display
for i in range(num_images_to_display):
    plt.figure(figsize=(10, 5))

    # Show original image
    plt.subplot(1, 2, 1)
    plt.imshow(images[i])
    plt.title('Original Image')
    plt.axis('off')

    # Show predicted mask
    plt.subplot(1, 2, 2)
    plt.imshow(binary_predictions[i][:, :, 0], cmap='gray')
    plt.title('Predicted Mask')
    plt.axis('off')

    plt.tight_layout()
    plt.show()
# Out:
# Skipped: /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (100)_mask_1.png or /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (100)_mask_1_mask.png
# Skipped: /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (163)_mask_1.png or /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (163)_mask_1_mask.png
# Skipped: /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (181)_mask_1.png or /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (181)_mask_1_mask.png
# Skipped: /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (173)_mask_1.png or /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (173)_mask_1_mask.png
# Skipped: /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (195)_mask_1.png or /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (195)_mask_1_mask.png
# Skipped: /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (195)_mask_2.png or /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (195)_mask_2_mask.png
# Skipped: /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (25)_mask_1.png or /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (25)_mask_1_mask.png
# Skipped: /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (315)_mask_1.png or /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (315)_mask_1_mask.png
# Skipped: /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (346)_mask_1.png or /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (346)_mask_1_mask.png
# Skipped: /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (4)_mask_1.png or /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (4)_mask_1_mask.png
# Skipped: /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (424)_mask_1.png or /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (424)_mask_1_mask.png
# Skipped: /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (54)_mask_1.png or /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (54)_mask_1_mask.png
# Skipped: /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (58)_mask_1.png or /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (58)_mask_1_mask.png
# Skipped: /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (83)_mask_1.png or /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (83)_mask_1_mask.png
# Skipped: /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (98)_mask_1.png or /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (98)_mask_1_mask.png
# Skipped: /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (93)_mask_1.png or /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (93)_mask_1_mask.png
# Skipped: /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (92)_mask_1.png or /content/drive/MyDrive/Dataset_BUSI_with_GT/benign/benign (92)_mask_1_mask.png
# Skipped: /content/drive/MyDrive/Dataset_BUSI_with_GT/malignant/malignant (53)_mask_1.png or /content/drive/MyDrive/Dataset_BUSI_with_GT/malignant/malignant (53)_mask_1_mask.png
# 25/25 [==============================] - 41s 2s/step

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# Load 'malignant' images and masks from the dataset
dataset_path = '/content/drive/MyDrive/Dataset_BUSI_with_GT'  # Update with your dataset path

folder = 'malignant'  # Select the 'malignant' folder
images = []
masks = []

size_x = 128
size_y = 128

folder_path = os.path.join(dataset_path, folder)
for filename in os.listdir(folder_path):
    if filename.endswith(".png") and not filename.endswith("_mask.png"):
        img_path = os.path.join(folder_path, filename)
        mask_path = os.path.join(folder_path, filename.replace(".png", "_mask.png"))

        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)  # Read mask as grayscale

        if img is not None and mask is not None:  # Check if both image and mask were read successfully
            img = cv2.resize(img, (size_y, size_x))
            mask = cv2.resize(mask, (size_y, size_x))

            images.append(img)
            masks.append(mask)
        else:
            print(f"Skipped: {img_path} or {mask_path}")

# Convert images and masks to numpy arrays
images = np.array(images)
masks = np.array(masks)

x = images / 255  # Normalize images
y = masks / 255  # Normalize masks

# Make predictions using the trained model
predictions = model.predict(x)

# Threshold the predictions if needed
threshold = 0.5  # Adjust the threshold as needed
binary_predictions = (predictions > threshold).astype(np.uint8)

# Display a few malignant predictions
num_images_to_display = 3  # Change this to set the number of images to display
for i in range(num_images_to_display):
    plt.figure(figsize=(10, 5))

    # Show original image
    plt.subplot(1, 2, 1)
    plt.imshow(images[i])
    plt.title('Original Image')
    plt.axis('off')

    # Show predicted mask (malignant class)
    plt.subplot(1, 2, 2)
    plt.imshow(binary_predictions[i][:, :, 0], cmap='gray')
    plt.title('Malignant Prediction')
    plt.axis('off')

    plt.tight_layout()
    plt.show()
# Out:
# Skipped: /content/drive/MyDrive/Dataset_BUSI_with_GT/malignant/malignant (53)_mask_1.png or /content/drive/MyDrive/Dataset_BUSI_with_GT/malignant/malignant (53)_mask_1_mask.png
# 7/7 [==============================] - 9s 1s/step
